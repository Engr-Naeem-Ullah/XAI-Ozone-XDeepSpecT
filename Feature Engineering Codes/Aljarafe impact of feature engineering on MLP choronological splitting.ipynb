# %% [markdown]
# MLP with out feature engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # # Create lag features with a window size of 24
    # lags = 24
    # for i in range(1, lags + 1):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # # Add rolling statistics (mean, std, skewness) with a window size of 24
    # df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    # df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    # df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.625428199768066, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -14.63    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.432830810546875, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -14.43    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.851037979125977, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -14.85    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.584015846252441, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -14.58    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.389215469360352, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -14.39    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.398543357849121, Units: 90, Dropout: 0.194, Activation: relu, Epochs: 56, Batch Size: 16
# | 6         | -14.4     | 0.493     | 16.43     | 0.1942    | 56.89     | 90.77     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.341191291809082, Units: 76, Dropout: 0.302, Activation: relu, Epochs: 67, Batch Size: 21
# | 7         | -14.34    | 0.1289    | 21.84     | 0.3025    | 67.62     | 76.14     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.300904273986816, Units: 74, Dropout: 0.188, Activation: relu, Epochs: 55, Batch Size: 18
# | 8         | -14.3     | 0.7273    | 18.12     | 0.1875    | 55.51     | 74.85     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.755017280578613, Units: 84, Dropout: 0.198, Activation: tanh, Epochs: 52, Batch Size: 33
# | 9         | -14.76    | 1.063     | 33.24     | 0.1984    | 52.54     | 84.21     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.17507266998291, Units: 85, Dropout: 0.153, Activation: relu, Epochs: 66, Batch Size: 16
# | 10        | -14.18    | 0.3244    | 16.06     | 0.1534    | 66.5      | 85.36     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.517973899841309, Units: 77, Dropout: 0.340, Activation: relu, Epochs: 87, Batch Size: 16
# | 11        | -14.52    | 0.4254    | 16.11     | 0.3398    | 87.88     | 77.21     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.3632230758667, Units: 47, Dropout: 0.451, Activation: relu, Epochs: 50, Batch Size: 16
# | 12        | -14.36    | 0.5084    | 16.97     | 0.451     | 50.6      | 47.85     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.361804962158203, Units: 127, Dropout: 0.150, Activation: tanh, Epochs: 98, Batch Size: 60
# | 13        | -14.36    | 1.884     | 60.67     | 0.1503    | 98.49     | 127.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.35878849029541, Units: 127, Dropout: 0.273, Activation: tanh, Epochs: 98, Batch Size: 36
# | 14        | -14.36    | 1.806     | 36.59     | 0.2732    | 98.24     | 128.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.473860740661621, Units: 127, Dropout: 0.398, Activation: relu, Epochs: 76, Batch Size: 50
# | 15        | -14.47    | 0.5644    | 50.14     | 0.3979    | 76.4      | 127.7     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.53437328338623, Units: 109, Dropout: 0.429, Activation: tanh, Epochs: 99, Batch Size: 46
# | 16        | -14.53    | 1.935     | 46.34     | 0.429     | 99.8      | 109.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.19318675994873, Units: 124, Dropout: 0.150, Activation: relu, Epochs: 96, Batch Size: 16
# | 17        | -14.19    | 0.5664    | 16.71     | 0.1499    | 96.48     | 124.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.321044921875, Units: 127, Dropout: 0.152, Activation: relu, Epochs: 83, Batch Size: 17
# | 18        | -14.32    | 0.1468    | 17.62     | 0.152     | 83.91     | 128.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.341035842895508, Units: 112, Dropout: 0.129, Activation: tanh, Epochs: 99, Batch Size: 18
# | 19        | -14.34    | 1.022     | 18.08     | 0.1289    | 99.57     | 112.7     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 14.311623573303223, Units: 32, Dropout: 0.122, Activation: relu, Epochs: 98, Batch Size: 16
# | 20        | -14.31    | 0.05117   | 16.3      | 0.1216    | 98.27     | 32.32     |
# =====================================================================================
# Best Parameters: {'activation': 0.32442018095164693, 'batch_size': 16.06273997363678, 'dropout_rate': 0.15337612985930496, 'epochs': 66.50217589382243, 'num_units': 85.35718807916186}
# Epoch 1/66
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1797/1797 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 1184.3353 - mae: 25.2024 - val_loss: 423.3088 - val_mae: 16.7495
# Epoch 2/66
# 1797/1797 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 266.3436 - mae: 12.9024 - val_loss: 361.3200 - val_mae: 15.5287
# Epoch 3/66
# 1797/1797 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss:
66
# 1797/1797 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 224.2766 - mae: 11.8337 - val_loss: 312.1768 - val_mae: 14.3407
# Epoch 66/66
# 1797/1797 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 222.9670 - mae: 11.8051 - val_loss: 372.4668 - val_mae: 15.6013
# Test MAE: 16.1449
# Test RMSE: 19.9136

# %% [markdown]
# MLP BM + Rolling statistics features only

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # # Create lag features with a window size of 24
    # lags = 24
    # for i in range(1, lags + 1):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Add rolling statistics (mean, std, skewness) with a window size of 24
    df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.7581787109375, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -12.76    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.090816497802734, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -12.09    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.40111255645752, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -12.4     | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.240914344787598, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -12.24    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.11455249786377, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -12.11    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.036909103393555, Units: 102, Dropout: 0.468, Activation: relu, Epochs: 52, Batch Size: 24
# | 6         | -12.04    | 0.4611    | 24.4      | 0.4682    | 52.2      | 102.5     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.785499572753906, Units: 103, Dropout: 0.451, Activation: relu, Epochs: 53, Batch Size: 24
# | 7         | -11.79    | 0.6573    | 24.19     | 0.4514    | 53.53     | 103.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.976983070373535, Units: 105, Dropout: 0.327, Activation: relu, Epochs: 54, Batch Size: 22
# | 8         | -11.98    | 0.9962    | 22.23     | 0.3271    | 54.68     | 105.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.726122856140137, Units: 106, Dropout: 0.231, Activation: relu, Epochs: 53, Batch Size: 25
# | 9         | -11.73    | 0.6101    | 25.46     | 0.2308    | 53.06     | 106.5     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.678919792175293, Units: 107, Dropout: 0.322, Activation: relu, Epochs: 56, Batch Size: 27
# | 10        | -11.68    | 0.7623    | 27.95     | 0.3216    | 56.96     | 107.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.791574478149414, Units: 103, Dropout: 0.156, Activation: relu, Epochs: 56, Batch Size: 28
# | 11        | -11.79    | 0.01355   | 28.7      | 0.1557    | 56.23     | 103.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.914183616638184, Units: 110, Dropout: 0.426, Activation: relu, Epochs: 55, Batch Size: 31
# | 12        | -11.91    | 0.6002    | 31.66     | 0.4259    | 55.23     | 110.5     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.74462604522705, Units: 104, Dropout: 0.175, Activation: relu, Epochs: 61, Batch Size: 26
# | 13        | -11.74    | 0.2642    | 26.21     | 0.1746    | 61.1      | 104.9     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.924379348754883, Units: 111, Dropout: 0.346, Activation: tanh, Epochs: 59, Batch Size: 25
# | 14        | -11.92    | 1.01      | 25.67     | 0.3455    | 59.82     | 111.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.904892921447754, Units: 107, Dropout: 0.476, Activation: tanh, Epochs: 60, Batch Size: 30
# | 15        | -11.9     | 1.773     | 30.18     | 0.4763    | 60.87     | 107.5     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.053827285766602, Units: 99, Dropout: 0.155, Activation: tanh, Epochs: 60, Batch Size: 26
# | 16        | -12.05    | 1.579     | 26.67     | 0.1553    | 60.02     | 99.05     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.947474479675293, Units: 104, Dropout: 0.168, Activation: relu, Epochs: 65, Batch Size: 22
# | 17        | -11.95    | 0.007615  | 22.17     | 0.168     | 65.74     | 104.4     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.687243461608887, Units: 112, Dropout: 0.384, Activation: relu, Epochs: 50, Batch Size: 26
# | 18        | -11.69    | 0.9835    | 26.99     | 0.384     | 50.57     | 112.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.967227935791016, Units: 117, Dropout: 0.296, Activation: tanh, Epochs: 51, Batch Size: 28
# | 19        | -11.97    | 1.806     | 28.44     | 0.2961    | 51.16     | 117.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.090197563171387, Units: 109, Dropout: 0.405, Activation: tanh, Epochs: 50, Batch Size: 28
# | 20        | -12.09    | 1.255     | 28.19     | 0.4048    | 50.24     | 109.5     |
# =====================================================================================
# Best Parameters: {'activation': 0.7623190826199402, 'batch_size': 27.947532888135633, 'dropout_rate': 0.32160966033123806, 'epochs': 56.95543477496969, 'num_units': 107.12539366809597}
# Epoch 1/56
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 
56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 179.5295 - mae: 10.4429 - val_loss: 245.8468 - val_mae: 12.4493
# Epoch 33/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 174.6066 - mae: 10.3499 - val_loss: 246.7755 - val_mae: 12.4728
# Epoch 34/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 175.8959 - mae: 10.3624 - val_loss: 236.9820 - val_mae: 12.2446
# Epoch 35/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 175.6043 - mae: 10.3827 - val_loss: 251.4572 - val_mae: 12.5571
# Epoch 36/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 173.2036 - mae: 10.2645 - val_loss: 242.3784 - val_mae: 12.3150
# Epoch 37/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 178.3670 - mae: 10.4237 - val_loss: 246.5290 - val_mae: 12.4239
# Epoch 38/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 176.5930 - mae: 10.3795 - val_loss: 282.0491 - val_mae: 13.2452
# Epoch 39/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 174.1634 - mae: 10.3250 - val_loss: 226.6950 - val_mae: 11.9637
# Epoch 40/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 174.2023 - mae: 10.3231 - val_loss: 256.3973 - val_mae: 12.6905
# Epoch 41/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 168.5533 - mae: 10.1286 - val_loss: 252.9721 - val_mae: 12.5451
# Epoch 42/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 172.0449 - mae: 10.2427 - val_loss: 241.2040 - val_mae: 12.3057
# Epoch 43/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 168.8451 - mae: 10.1536 - val_loss: 228.3124 - val_mae: 11.9575
# Epoch 44/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 170.2880 - mae: 10.1758 - val_loss: 231.6109 - val_mae: 12.1007
# Epoch 45/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 170.9901 - mae: 10.2196 - val_loss: 248.3639 - val_mae: 12.4421
# Epoch 46/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 170.0703 - mae: 10.1868 - val_loss: 243.9083 - val_mae: 12.3287
# Epoch 47/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 168.3351 - mae: 10.1060 - val_loss: 254.9100 - val_mae: 12.6340
# Epoch 48/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 168.9202 - mae: 10.0956 - val_loss: 255.6500 - val_mae: 12.5887
# Epoch 49/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 169.5700 - mae: 10.0714 - val_loss: 253.4160 - val_mae: 12.5222
# Epoch 50/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 166.8863 - mae: 10.0933 - val_loss: 223.3253 - val_mae: 11.8471
# Epoch 51/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 170.3371 - mae: 10.1575 - val_loss: 229.1308 - val_mae: 11.9715
# Epoch 52/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 169.7047 - mae: 10.1510 - val_loss: 223.6384 - val_mae: 11.8492
# Epoch 53/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 173.2586 - mae: 10.2205 - val_loss: 254.2791 - val_mae: 12.5556
# Epoch 54/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 166.9957 - mae: 10.0633 - val_loss: 226.7448 - val_mae: 11.9121
# Epoch 55/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 167.8986 - mae: 10.0778 - val_loss: 222.7131 - val_mae: 11.8271
# Epoch 56/56
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 171.4091 - mae: 10.2394 - val_loss: 245.7509 - val_mae: 12.2720
# Test MAE: 13.4156
# Test RMSE: 16.8564

# %% [markdown]
# BM + Time-Based Features Only

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # # Create lag features with a window size of 24
    # lags = 24
    # for i in range(1, lags + 1):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # # Add rolling statistics (mean, std, skewness) with a window size of 24
    # df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    # df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    # df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    # Add hourly and daily aggregated features
    df['hour'] = df.index.hour
    df['day'] = df.index.day
    df['weekday'] = df.index.weekday
    df['month'] = df.index.month

    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.808977127075195, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -11.81    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.51996898651123, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -11.52    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.436874389648438, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -12.44    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.529025077819824, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -11.53    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.444693565368652, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -11.44    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.242454528808594, Units: 77, Dropout: 0.141, Activation: relu, Epochs: 88, Batch Size: 26
# | 6         | -11.24    | 0.7611    | 26.25     | 0.1409    | 88.59     | 77.02     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.752955436706543, Units: 77, Dropout: 0.453, Activation: tanh, Epochs: 88, Batch Size: 27
# | 7         | -11.75    | 1.865     | 27.07     | 0.4526    | 88.32     | 77.74     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.774053573608398, Units: 54, Dropout: 0.114, Activation: tanh, Epochs: 55, Batch Size: 18
# | 8         | -11.77    | 1.168     | 18.29     | 0.1143    | 55.23     | 54.39     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.207210540771484, Units: 62, Dropout: 0.469, Activation: relu, Epochs: 71, Batch Size: 63
# | 9         | -12.21    | 0.9372    | 63.66     | 0.4687    | 71.59     | 62.29     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.222665786743164, Units: 101, Dropout: 0.227, Activation: tanh, Epochs: 63, Batch Size: 24
# | 10        | -11.22    | 1.615     | 24.44     | 0.2267    | 63.44     | 101.7     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.34087085723877, Units: 108, Dropout: 0.394, Activation: relu, Epochs: 79, Batch Size: 28
# | 11        | -11.34    | 0.9826    | 28.27     | 0.3941    | 79.79     | 108.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.883963584899902, Units: 60, Dropout: 0.287, Activation: relu, Epochs: 65, Batch Size: 54
# | 12        | -11.88    | 0.1509    | 54.97     | 0.2867    | 65.29     | 60.68     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.341893196105957, Units: 103, Dropout: 0.337, Activation: relu, Epochs: 87, Batch Size: 59
# | 13        | -11.34    | 0.165     | 59.38     | 0.3375    | 87.49     | 103.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.82690715789795, Units: 83, Dropout: 0.498, Activation: tanh, Epochs: 70, Batch Size: 48
# | 14        | -11.83    | 1.456     | 48.04     | 0.4978    | 70.33     | 83.72     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 12.038701057434082, Units: 53, Dropout: 0.221, Activation: relu, Epochs: 59, Batch Size: 51
# | 15        | -12.04    | 0.2672    | 51.39     | 0.2205    | 59.48     | 53.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.274262428283691, Units: 124, Dropout: 0.125, Activation: relu, Epochs: 87, Batch Size: 47
# | 16        | -11.27    | 0.5428    | 47.28     | 0.1249    | 87.35     | 124.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.469231605529785, Units: 101, Dropout: 0.421, Activation: tanh, Epochs: 63, Batch Size: 24
# | 17        | -11.47    | 1.101     | 24.59     | 0.4209    | 63.04     | 101.5     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 10.888861656188965, Units: 123, Dropout: 0.285, Activation: relu, Epochs: 87, Batch Size: 47
# | 18        | -10.89    | 0.1666    | 47.84     | 0.2845    | 87.43     | 123.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.559549331665039, Units: 122, Dropout: 0.345, Activation: relu, Epochs: 88, Batch Size: 46
# | 19        | -11.56    | 0.648     | 46.39     | 0.345     | 88.41     | 122.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 11.492326736450195, Units: 121, Dropout: 0.185, Activation: tanh, Epochs: 88, Batch Size: 49
# | 20        | -11.49    | 1.189     | 49.03     | 0.1855    | 88.06     | 122.0     |
# =====================================================================================
# Best Parameters: {'activation': 0.16658228172425193, 'batch_size': 47.83910541496283, 'dropout_rate': 0.2845073454749285, 'epochs': 87.42876957797145, 'num_units': 123.30962770932645}
# Epoch 1/87
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1717.4604 - mae: 31.9728 - val_loss: 309.6703 - val_mae: 14.1571
# Epoch 2/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 249.7589 - mae: 12.5200 - val_loss: 308.1452 - val_mae: 14.0591
# Epoch 3/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1998 - mae: 12.0419 - val_loss: 299.7810 - val_mae: 13.8712
# Epoch 4/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 228.4807 - mae: 11.9020 - val_loss: 287.2060 - val_mae: 13.5816
# Epoch 5/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 218.4707 - mae: 11.6756 - val_loss: 315.2836 - val_mae: 14.1578
# Epoch 6/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss:
87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 159.9601 - mae: 9.9137 - val_loss: 239.6835 - val_mae: 12.2406
# Epoch 70/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.7903 - mae: 9.8773 - val_loss: 241.6463 - val_mae: 12.3271
# Epoch 71/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 161.2744 - mae: 9.9274 - val_loss: 230.6130 - val_mae: 12.0057
# Epoch 72/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.6860 - mae: 9.8632 - val_loss: 239.9341 - val_mae: 12.2455
# Epoch 73/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.9312 - mae: 9.8487 - val_loss: 225.2437 - val_mae: 11.8817
# Epoch 74/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 158.2294 - mae: 9.8405 - val_loss: 243.9058 - val_mae: 12.3799
# Epoch 75/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 155.7796 - mae: 9.7796 - val_loss: 222.1207 - val_mae: 11.7490
# Epoch 76/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 155.2318 - mae: 9.7961 - val_loss: 228.2912 - val_mae: 11.9316
# Epoch 77/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 157.7842 - mae: 9.8316 - val_loss: 237.2074 - val_mae: 12.1756
# Epoch 78/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 156.5011 - mae: 9.7742 - val_loss: 230.5222 - val_mae: 11.9946
# Epoch 79/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 157.0127 - mae: 9.8240 - val_loss: 243.6676 - val_mae: 12.3797
# Epoch 80/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 154.3478 - mae: 9.7472 - val_loss: 248.2949 - val_mae: 12.4653
# Epoch 81/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 153.6843 - mae: 9.7085 - val_loss: 232.8806 - val_mae: 12.0441
# Epoch 82/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 152.8325 - mae: 9.6936 - val_loss: 238.4065 - val_mae: 12.2144
# Epoch 83/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 156.1321 - mae: 9.7768 - val_loss: 222.1858 - val_mae: 11.7449
# Epoch 84/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 155.7675 - mae: 9.7856 - val_loss: 237.5900 - val_mae: 12.1840
# Epoch 85/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 152.6203 - mae: 9.6967 - val_loss: 217.1239 - val_mae: 11.6340
# Epoch 86/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 154.7639 - mae: 9.7380 - val_loss: 212.5151 - val_mae: 11.4898
# Epoch 87/87
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 152.9965 - mae: 9.6643 - val_loss: 220.0216 - val_mae: 11.7116
# Test MAE: 12.6909
# Test RMSE: 15.8032

# %% [markdown]
# BM + Lagging Features Only

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # Create lag features with a window size of 24
    lags = 24
    for i in range(1, lags + 1):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # # Add rolling statistics (mean, std, skewness) with a window size of 24
    # df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    # df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    # df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.035283088684082, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -5.035    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.7087202072143555, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -4.709    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.095987796783447, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -6.096    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.8150105476379395, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -4.815    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.541533946990967, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -4.542    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.605442523956299, Units: 81, Dropout: 0.261, Activation: tanh, Epochs: 82, Batch Size: 28
# | 6         | -4.605    | 1.829     | 28.18     | 0.2607    | 82.17     | 81.73     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.644126892089844, Units: 76, Dropout: 0.302, Activation: relu, Epochs: 67, Batch Size: 21
# | 7         | -4.644    | 0.1289    | 21.84     | 0.3025    | 67.62     | 76.14     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.693733215332031, Units: 84, Dropout: 0.354, Activation: tanh, Epochs: 65, Batch Size: 36
# | 8         | -4.694    | 1.728     | 36.62     | 0.3543    | 65.5      | 84.32     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.516701698303223, Units: 69, Dropout: 0.231, Activation: tanh, Epochs: 84, Batch Size: 16
# | 9         | -4.517    | 1.242     | 16.75     | 0.2307    | 84.94     | 69.66     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.553470134735107, Units: 63, Dropout: 0.173, Activation: tanh, Epochs: 98, Batch Size: 32
# | 10        | -4.553    | 1.596     | 32.63     | 0.1732    | 98.67     | 63.94     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.5400190353393555, Units: 51, Dropout: 0.172, Activation: tanh, Epochs: 99, Batch Size: 16
# | 11        | -4.54     | 1.717     | 16.04     | 0.1717    | 99.34     | 51.4      |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.856533527374268, Units: 39, Dropout: 0.411, Activation: relu, Epochs: 99, Batch Size: 34
# | 12        | -4.857    | 0.8535    | 34.34     | 0.4114    | 99.74     | 39.51     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.609955787658691, Units: 84, Dropout: 0.255, Activation: relu, Epochs: 99, Batch Size: 16
# | 13        | -4.61     | 0.169     | 16.01     | 0.2546    | 99.98     | 84.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.448022365570068, Units: 81, Dropout: 0.148, Activation: tanh, Epochs: 99, Batch Size: 44
# | 14        | -4.448    | 1.37      | 44.72     | 0.1477    | 99.87     | 81.59     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.4523138999938965, Units: 99, Dropout: 0.237, Activation: tanh, Epochs: 99, Batch Size: 52
# | 15        | -4.452    | 1.993     | 52.14     | 0.2375    | 99.47     | 99.36     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.792993545532227, Units: 86, Dropout: 0.401, Activation: relu, Epochs: 95, Batch Size: 62
# | 16        | -4.793    | 0.9497    | 62.62     | 0.4008    | 95.75     | 86.07     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.721402168273926, Units: 99, Dropout: 0.385, Activation: relu, Epochs: 99, Batch Size: 35
# | 17        | -4.721    | 0.7144    | 35.51     | 0.3854    | 99.94     | 99.8      |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.6817169189453125, Units: 118, Dropout: 0.450, Activation: tanh, Epochs: 98, Batch Size: 59
# | 18        | -4.682    | 1.994     | 59.6      | 0.4498    | 98.54     | 118.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.773407459259033, Units: 103, Dropout: 0.446, Activation: tanh, Epochs: 80, Batch Size: 51
# | 19        | -4.773    | 1.392     | 51.22     | 0.446     | 80.16     | 103.4     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.742866516113281, Units: 65, Dropout: 0.366, Activation: relu, Epochs: 99, Batch Size: 51
# | 20        | -4.743    | 0.03468   | 51.65     | 0.3664    | 99.15     | 65.52     |
# =====================================================================================
# Best Parameters: {'activation': 1.3703386629079182, 'batch_size': 44.71692911199764, 'dropout_rate': 0.14773073101522616, 'epochs': 99.87158320864062, 'num_units': 81.59048387115624}
# Epoch 1/99
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2790.7617 - mae: 45.3139 - val_loss: 1161.8347 - val_mae: 27.8993
# Epoch 2/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1205.0287 - mae: 27.5105 - val_loss: 500.5597 - val_mae: 16.9530
# Epoch 3/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 555.6028 - mae: 16.9705 - val_loss: 246.7220 - val_mae: 11.6211
# Epoch 4/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 301.7823 - mae: 11.8543 - val_loss: 131.5925 - val_mae: 8.1465
# Epoch 5/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 180.0216 - mae: 9.0932 - val_loss: 89.5166 - val_mae: 6.7570
# Epoch 6/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 128.1043 - mae: 7.6880 - val_loss: 71.2307 - val_mae: 6.0981
# Epoch 7/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 94.1947 - mae: 6.7163 - val_loss: 60.7564 - val_mae: 5.6429
# Epoch 8/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 79.0493 - mae: 6.2227 - val_loss: 56.4978 - val_mae: 5.5029
# Epoch 9/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 65.9853 - mae: 5.8585 - val_loss: 54.8192 - val_mae: 5.4403
# Epoch 10/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 63.4208 - mae: 5.6886 - val_loss: 51.3845 - val_mae: 5.2521
# Epoch 11/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 59.6078 - mae: 5.6228 - val_loss: 55.7557 - val_mae: 5.5702
# Epoch 12/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55.6565 - mae: 5.4707 - val_loss: 57.8919 - val_mae: 5.7153
# Epoch 13/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 56.1050 - mae: 5.4939 - val_loss: 52.7425 - val_mae: 5.3784
# Epoch 14/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 
99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.8615 - mae: 4.6978 - val_loss: 42.7463 - val_mae: 4.7665
# Epoch 80/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.6703 - mae: 4.6987 - val_loss: 40.7907 - val_mae: 4.6260
# Epoch 81/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.9468 - mae: 4.7345 - val_loss: 39.7620 - val_mae: 4.5876
# Epoch 82/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.2427 - mae: 4.6993 - val_loss: 41.0932 - val_mae: 4.6841
# Epoch 83/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.9590 - mae: 4.6983 - val_loss: 42.2746 - val_mae: 4.7291
# Epoch 84/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.9950 - mae: 4.7075 - val_loss: 39.7188 - val_mae: 4.5714
# Epoch 85/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.8008 - mae: 4.7063 - val_loss: 41.4606 - val_mae: 4.6778
# Epoch 86/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.4742 - mae: 4.7617 - val_loss: 38.9955 - val_mae: 4.5124
# Epoch 87/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.3465 - mae: 4.6935 - val_loss: 43.1386 - val_mae: 4.8224
# Epoch 88/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.0047 - mae: 4.6520 - val_loss: 42.9509 - val_mae: 4.7754
# Epoch 89/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.3481 - mae: 4.7188 - val_loss: 40.7187 - val_mae: 4.6624
# Epoch 90/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 39.7371 - mae: 4.6464 - val_loss: 40.3022 - val_mae: 4.5911
# Epoch 91/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.7887 - mae: 4.6561 - val_loss: 42.4292 - val_mae: 4.7580
# Epoch 92/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.9284 - mae: 4.6809 - val_loss: 40.2753 - val_mae: 4.5942
# Epoch 93/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.2193 - mae: 4.7074 - val_loss: 38.5842 - val_mae: 4.4350
# Epoch 94/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.1968 - mae: 4.6568 - val_loss: 42.7744 - val_mae: 4.7948
# Epoch 95/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.0364 - mae: 4.6793 - val_loss: 42.8010 - val_mae: 4.8093
# Epoch 96/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.2111 - mae: 4.6640 - val_loss: 41.0231 - val_mae: 4.6562
# Epoch 97/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.2180 - mae: 4.7156 - val_loss: 39.9480 - val_mae: 4.5915
# Epoch 98/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.1011 - mae: 4.6446 - val_loss: 41.5389 - val_mae: 4.6817
# Epoch 99/99
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40.1085 - mae: 4.6429 - val_loss: 42.2669 - val_mae: 4.7668
# Test MAE: 6.0877
# Test RMSE: 8.0678

# %% [markdown]
# BM+ Lagging Features + Rolling Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # Create lag features with a window size of 24
    lags = 24
    for i in range(1, lags + 1):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Add rolling statistics (mean, std, skewness) with a window size of 24
    df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.989027976989746, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -4.989    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.655296325683594, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -4.655    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.844923496246338, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -5.845    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.897434234619141, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -4.897    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 2.2423171997070312, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -2.242    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.107283115386963, Units: 90, Dropout: 0.203, Activation: relu, Epochs: 91, Batch Size: 49
# | 6         | -4.107    | 0.7742    | 49.17     | 0.2032    | 91.6      | 90.54     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 0.589843213558197, Units: 105, Dropout: 0.159, Activation: tanh, Epochs: 96, Batch Size: 21
# | 7         | -0.5898   | 1.813     | 21.06     | 0.1589    | 96.26     | 106.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.2926454544067383, Units: 54, Dropout: 0.114, Activation: tanh, Epochs: 55, Batch Size: 18
# | 8         | -3.293    | 1.168     | 18.29     | 0.1143    | 55.23     | 54.39     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.247833251953125, Units: 62, Dropout: 0.469, Activation: relu, Epochs: 71, Batch Size: 63
# | 9         | -5.248    | 0.9372    | 63.66     | 0.4687    | 71.59     | 62.29     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.721961975097656, Units: 75, Dropout: 0.259, Activation: relu, Epochs: 67, Batch Size: 22
# | 10        | -4.722    | 0.09682   | 22.17     | 0.259     | 67.9      | 75.93     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.404865741729736, Units: 108, Dropout: 0.394, Activation: relu, Epochs: 79, Batch Size: 28
# | 11        | -4.405    | 0.9826    | 28.27     | 0.3941    | 79.79     | 108.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.269686222076416, Units: 60, Dropout: 0.287, Activation: relu, Epochs: 65, Batch Size: 54
# | 12        | -5.27     | 0.1509    | 54.97     | 0.2867    | 65.29     | 60.68     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.3035101890563965, Units: 103, Dropout: 0.337, Activation: relu, Epochs: 87, Batch Size: 59
# | 13        | -4.304    | 0.165     | 59.38     | 0.3375    | 87.49     | 103.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.58074951171875, Units: 83, Dropout: 0.498, Activation: tanh, Epochs: 70, Batch Size: 48
# | 14        | -4.581    | 1.456     | 48.04     | 0.4978    | 70.33     | 83.72     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.427933692932129, Units: 53, Dropout: 0.221, Activation: relu, Epochs: 59, Batch Size: 51
# | 15        | -4.428    | 0.2672    | 51.39     | 0.2205    | 59.48     | 53.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.364542007446289, Units: 124, Dropout: 0.125, Activation: relu, Epochs: 87, Batch Size: 47
# | 16        | -3.365    | 0.5428    | 47.28     | 0.1249    | 87.35     | 124.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.6838395595550537, Units: 108, Dropout: 0.195, Activation: relu, Epochs: 95, Batch Size: 20
# | 17        | -3.684    | 0.3276    | 20.85     | 0.1952    | 95.61     | 108.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.386654376983643, Units: 47, Dropout: 0.435, Activation: tanh, Epochs: 96, Batch Size: 33
# | 18        | -4.387    | 1.555     | 33.16     | 0.435     | 96.73     | 47.66     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.257441997528076, Units: 120, Dropout: 0.417, Activation: tanh, Epochs: 66, Batch Size: 40
# | 19        | -4.257    | 1.011     | 40.56     | 0.4166    | 66.52     | 120.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.364158630371094, Units: 59, Dropout: 0.267, Activation: tanh, Epochs: 59, Batch Size: 43
# | 20        | -4.364    | 1.728     | 43.46     | 0.2665    | 59.16     | 59.02     |
# =====================================================================================
# Best Parameters: {'activation': 1.812765080381792, 'batch_size': 21.05712181809413, 'dropout_rate': 0.15890981822640435, 'epochs': 96.26443771889072, 'num_units': 105.98762279823745}
# Epoch 1/96
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1993.0499 - mae: 36.3605 - val_loss: 286.4223 - val_mae: 12.4840
# Epoch 2/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 300.6905 - mae: 11.9055 - val_loss: 87.8176 - val_mae: 6.8373
# Epoch 3/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 110.7177 - mae: 7.2972 - val_loss: 65.0137 - val_mae: 6.0139
# Epoch 4/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73.2259 - mae: 6.0975 - val_loss: 57.9669 - val_mae: 5.7461
# Epoch 5/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 61.6159 - mae: 5.6895 - val_loss: 48.1911 - val_mae: 5.0918
# Epoch 6/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 56.2606 - mae: 5.5204 - val_loss: 49.4394 - val_mae: 5.1976
# Epoch 7/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 55.7480 - mae: 5.4369 - val_loss: 55.6556 - val_mae: 5.6537
# Epoch 8/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 51.8635 - mae: 5.3137 - val_loss: 46.2319 - val_mae: 4.9949
# Epoch 9/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 50.2775 - mae: 5.2029 - val_loss: 45.1945 - val_mae: 4.9028
# Epoch 10/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 49.9403 - mae: 5.1886 - val_loss: 51.6199 - val_mae: 5.3444
# Epoch 11/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 49.8227 - mae: 5.1678 - val_loss: 42.6968 - val_mae: 4.7407
# Epoch 12/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 47.8448 - mae: 5.1324 - val_loss: 47.2685 - val_mae: 5.0573
# Epoch 13/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss:
96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.4786 - mae: 2.1057 - val_loss: 1.9118 - val_mae: 1.0877
# Epoch 78/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.4426 - mae: 2.0924 - val_loss: 3.6679 - val_mae: 1.6342
# Epoch 79/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.8792 - mae: 2.0302 - val_loss: 1.4437 - val_mae: 0.9056
# Epoch 80/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.3665 - mae: 2.0931 - val_loss: 1.5767 - val_mae: 0.9959
# Epoch 81/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.2858 - mae: 2.0704 - val_loss: 1.7205 - val_mae: 1.0108
# Epoch 82/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.0864 - mae: 1.9018 - val_loss: 3.0332 - val_mae: 1.3858
# Epoch 83/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.9029 - mae: 2.0300 - val_loss: 1.6317 - val_mae: 1.0611
# Epoch 84/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.4531 - mae: 1.9656 - val_loss: 5.6748 - val_mae: 2.1407
# Epoch 85/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.8658 - mae: 2.0214 - val_loss: 0.9387 - val_mae: 0.7432
# Epoch 86/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.4430 - mae: 1.9467 - val_loss: 1.1047 - val_mae: 0.8123
# Epoch 87/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.0449 - mae: 1.8920 - val_loss: 0.8410 - val_mae: 0.6936
# Epoch 88/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.7882 - mae: 1.8400 - val_loss: 0.9124 - val_mae: 0.7416
# Epoch 89/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.2484 - mae: 1.9335 - val_loss: 1.5211 - val_mae: 0.9646
# Epoch 90/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.2050 - mae: 1.9012 - val_loss: 3.1702 - val_mae: 1.5792
# Epoch 91/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.9373 - mae: 1.8624 - val_loss: 1.4684 - val_mae: 0.9754
# Epoch 92/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.6383 - mae: 1.8254 - val_loss: 2.5978 - val_mae: 1.3300
# Epoch 93/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.1042 - mae: 1.9072 - val_loss: 4.4644 - val_mae: 1.9327
# Epoch 94/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.7026 - mae: 1.8441 - val_loss: 5.3916 - val_mae: 2.1480
# Epoch 95/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.7873 - mae: 1.8687 - val_loss: 8.0944 - val_mae: 2.6574
# Epoch 96/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.3315 - mae: 1.9591 - val_loss: 0.8721 - val_mae: 0.6937
# Test MAE: 0.8865
# Test RMSE: 1.2457

# %% [markdown]
# BM + Lagging Features + Time-Based Features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # Create lag features with a window size of 24
    lags = 24
    for i in range(1, lags + 1):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # # Add rolling statistics (mean, std, skewness) with a window size of 24
    # df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    # df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    # df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    # Add hourly and daily aggregated features
    df['hour'] = df.index.hour
    df['day'] = df.index.day
    df['weekday'] = df.index.weekday
    df['month'] = df.index.month

    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.984206199645996, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -4.984    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.742897987365723, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -4.743    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.895247459411621, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -5.895    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.416506767272949, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -5.417    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.420146942138672, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -4.42     | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.451299667358398, Units: 90, Dropout: 0.203, Activation: relu, Epochs: 91, Batch Size: 49
# | 6         | -4.451    | 0.7742    | 49.17     | 0.2032    | 91.6      | 90.54     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.211301803588867, Units: 105, Dropout: 0.159, Activation: tanh, Epochs: 96, Batch Size: 21
# | 7         | -4.211    | 1.813     | 21.06     | 0.1589    | 96.26     | 106.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.665065765380859, Units: 107, Dropout: 0.274, Activation: relu, Epochs: 96, Batch Size: 21
# | 8         | -4.665    | 0.7502    | 21.42     | 0.2736    | 96.04     | 107.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.353605270385742, Units: 106, Dropout: 0.406, Activation: tanh, Epochs: 96, Batch Size: 18
# | 9         | -4.354    | 1.905     | 18.51     | 0.4058    | 96.05     | 106.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.2994866371154785, Units: 103, Dropout: 0.152, Activation: relu, Epochs: 97, Batch Size: 21
# | 10        | -4.299    | 0.7344    | 21.73     | 0.1519    | 97.11     | 103.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.343236923217773, Units: 103, Dropout: 0.337, Activation: tanh, Epochs: 93, Batch Size: 22
# | 11        | -4.343    | 1.414     | 22.37     | 0.337     | 93.21     | 103.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.529175758361816, Units: 101, Dropout: 0.407, Activation: tanh, Epochs: 94, Batch Size: 17
# | 12        | -4.529    | 1.205     | 17.55     | 0.4071    | 94.66     | 101.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.388289928436279, Units: 102, Dropout: 0.398, Activation: tanh, Epochs: 96, Batch Size: 28
# | 13        | -4.388    | 1.799     | 28.46     | 0.3979    | 96.56     | 102.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.615206241607666, Units: 99, Dropout: 0.466, Activation: tanh, Epochs: 93, Batch Size: 25
# | 14        | -4.615    | 1.058     | 25.71     | 0.4664    | 93.65     | 99.14     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.469446182250977, Units: 102, Dropout: 0.457, Activation: tanh, Epochs: 99, Batch Size: 18
# | 15        | -4.469    | 1.729     | 18.14     | 0.4574    | 99.95     | 102.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.651350975036621, Units: 79, Dropout: 0.323, Activation: relu, Epochs: 64, Batch Size: 19
# | 16        | -4.651    | 0.3693    | 19.96     | 0.3229    | 64.34     | 79.59     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.3570709228515625, Units: 105, Dropout: 0.369, Activation: tanh, Epochs: 98, Batch Size: 25
# | 17        | -4.357    | 1.98      | 25.28     | 0.3689    | 98.45     | 105.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.824642181396484, Units: 76, Dropout: 0.481, Activation: tanh, Epochs: 74, Batch Size: 20
# | 18        | -4.825    | 1.143     | 20.34     | 0.4807    | 74.28     | 76.68     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.272166728973389, Units: 105, Dropout: 0.177, Activation: tanh, Epochs: 99, Batch Size: 32
# | 19        | -4.272    | 1.991     | 32.89     | 0.1774    | 99.86     | 105.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.279796123504639, Units: 102, Dropout: 0.198, Activation: tanh, Epochs: 96, Batch Size: 35
# | 20        | -4.28     | 1.666     | 35.29     | 0.1978    | 96.89     | 102.1     |
# =====================================================================================
# Best Parameters: {'activation': 1.812765080381792, 'batch_size': 21.05712181809413, 'dropout_rate': 0.15890981822640435, 'epochs': 96.26443771889072, 'num_units': 105.98762279823745}
# Epoch 1/96
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2054.6519 - mae: 36.9150 - val_loss: 293.7849 - val_mae: 12.5741
# Epoch 2/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 303.9809 - mae: 12.0421 - val_loss: 86.8064 - val_mae: 6.7858
# Epoch 3/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 111.1985 - mae: 7.3310 - val_loss: 60.5027 - val_mae: 5.7537
# Epoch 4/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.9265 - mae: 6.1580 - val_loss: 64.0920 - val_mae: 6.1467
# Epoch 5/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 63.4597 - mae: 5.8233 - val_loss: 53.7773 - val_mae: 5.4887
# Epoch 6/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 57.3215 - mae: 5.5506 - val_loss: 52.6763 - val_mae: 5.4142
# Epoch 7/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 54.9753 - mae: 5.4896 - val_loss: 49.3151 - val_mae: 5.2385
# Epoch 8/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 54.2048 - mae: 5.4491 - val_loss: 51.7046 - val_mae: 5.3638
# Epoch 9/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 52.2796 - mae: 5.3397 - val_loss: 46.0892 - val_mae: 4.9988
# Epoch 10/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 51.4559 - mae: 5.2883 - val_loss: 45.1523 - val_mae: 4.9620
# Epoch 11/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 50.2688 - mae: 5.2259 - val_loss: 47.3940 - val_mae: 5.0951
# Epoch 12/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss:
96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 37.3147 - mae: 4.5169 - val_loss: 43.2733 - val_mae: 4.8992
# Epoch 77/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.0766 - mae: 4.4638 - val_loss: 34.6517 - val_mae: 4.2472
# Epoch 78/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 36.0847 - mae: 4.4741 - val_loss: 34.5058 - val_mae: 4.2804
# Epoch 79/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 36.3918 - mae: 4.4656 - val_loss: 36.0308 - val_mae: 4.3768
# Epoch 80/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.9531 - mae: 4.4537 - val_loss: 38.0113 - val_mae: 4.5313
# Epoch 81/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.8000 - mae: 4.4923 - val_loss: 36.4933 - val_mae: 4.4043
# Epoch 82/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.0689 - mae: 4.4665 - val_loss: 34.6685 - val_mae: 4.2311
# Epoch 83/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.3046 - mae: 4.4585 - val_loss: 39.1487 - val_mae: 4.6015
# Epoch 84/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.5240 - mae: 4.4200 - val_loss: 38.8897 - val_mae: 4.6138
# Epoch 85/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 36.3088 - mae: 4.4731 - val_loss: 38.8572 - val_mae: 4.5803
# Epoch 86/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 35.6581 - mae: 4.4375 - val_loss: 34.1717 - val_mae: 4.2447
# Epoch 87/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.6993 - mae: 4.4262 - val_loss: 37.7843 - val_mae: 4.4934
# Epoch 88/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 34.9450 - mae: 4.4024 - val_loss: 35.0855 - val_mae: 4.2976
# Epoch 89/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.2175 - mae: 4.4231 - val_loss: 36.9204 - val_mae: 4.4597
# Epoch 90/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.7702 - mae: 4.5071 - val_loss: 36.7888 - val_mae: 4.4671
# Epoch 91/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.0122 - mae: 4.4110 - val_loss: 35.8768 - val_mae: 4.4015
# Epoch 92/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 36.1863 - mae: 4.4706 - val_loss: 35.3432 - val_mae: 4.3433
# Epoch 93/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 36.6686 - mae: 4.4927 - val_loss: 35.4678 - val_mae: 4.3746
# Epoch 94/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.5454 - mae: 4.4538 - val_loss: 35.9411 - val_mae: 4.3573
# Epoch 95/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 35.6965 - mae: 4.4178 - val_loss: 35.6441 - val_mae: 4.3442
# Epoch 96/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 34.5661 - mae: 4.3687 - val_loss: 41.3191 - val_mae: 4.8326
# Test MAE: 5.9030
# Test RMSE: 7.7325

# %% [markdown]
# BM + Rolling Statistics + Time-Based Features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # # Create lag features with a window size of 24
    # lags = 24
    # for i in range(1, lags + 1):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Add rolling statistics (mean, std, skewness) with a window size of 24
    df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    # Add hourly and daily aggregated features
    df['hour'] = df.index.hour
    df['day'] = df.index.day
    df['weekday'] = df.index.weekday
    df['month'] = df.index.month

    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 8.303108215332031, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -8.303    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.209561824798584, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -7.21     | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 8.581160545349121, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -8.581    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.418277263641357, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -7.418    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.938549518585205, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -6.939    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.180112838745117, Units: 106, Dropout: 0.455, Activation: relu, Epochs: 50, Batch Size: 16
# | 6         | -7.18     | 0.9741    | 16.0      | 0.4555    | 50.38     | 106.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.900248050689697, Units: 76, Dropout: 0.302, Activation: relu, Epochs: 67, Batch Size: 21
# | 7         | -6.9      | 0.1289    | 21.84     | 0.3025    | 67.62     | 76.14     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.894713878631592, Units: 126, Dropout: 0.265, Activation: relu, Epochs: 99, Batch Size: 62
# | 8         | -6.895    | 0.4288    | 62.74     | 0.2653    | 99.33     | 126.9     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.08397102355957, Units: 127, Dropout: 0.215, Activation: relu, Epochs: 51, Batch Size: 62
# | 9         | -7.084    | 0.07057   | 62.77     | 0.2155    | 51.62     | 127.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.883770942687988, Units: 66, Dropout: 0.222, Activation: relu, Epochs: 99, Batch Size: 16
# | 10        | -6.884    | 0.9101    | 16.15     | 0.2225    | 99.53     | 66.36     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 9.54681396484375, Units: 32, Dropout: 0.296, Activation: relu, Epochs: 98, Batch Size: 17
# | 11        | -9.547    | 0.07337   | 17.81     | 0.2956    | 98.12     | 32.18     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.778858184814453, Units: 92, Dropout: 0.140, Activation: relu, Epochs: 98, Batch Size: 50
# | 12        | -6.779    | 0.3098    | 50.46     | 0.1398    | 98.71     | 92.62     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.50324010848999, Units: 126, Dropout: 0.159, Activation: relu, Epochs: 99, Batch Size: 29
# | 13        | -6.503    | 0.6431    | 29.38     | 0.1593    | 99.06     | 126.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.834400177001953, Units: 127, Dropout: 0.406, Activation: tanh, Epochs: 76, Batch Size: 38
# | 14        | -6.834    | 1.705     | 38.31     | 0.4063    | 76.35     | 127.9     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.9194016456604, Units: 89, Dropout: 0.336, Activation: relu, Epochs: 99, Batch Size: 23
# | 15        | -6.919    | 0.5703    | 23.48     | 0.3359    | 99.89     | 89.05     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.870127201080322, Units: 103, Dropout: 0.257, Activation: tanh, Epochs: 73, Batch Size: 63
# | 16        | -6.87     | 1.303     | 63.84     | 0.2568    | 73.45     | 103.2     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.2282867431640625, Units: 66, Dropout: 0.317, Activation: relu, Epochs: 50, Batch Size: 16
# | 17        | -7.228    | 0.5893    | 16.11     | 0.3174    | 50.01     | 66.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.66425895690918, Units: 127, Dropout: 0.129, Activation: relu, Epochs: 95, Batch Size: 16
# | 18        | -6.664    | 0.5611    | 16.08     | 0.1293    | 95.24     | 127.4     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 7.078352451324463, Units: 96, Dropout: 0.277, Activation: tanh, Epochs: 50, Batch Size: 46
# | 19        | -7.078    | 1.614     | 46.06     | 0.2767    | 50.51     | 96.09     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 6.685365676879883, Units: 113, Dropout: 0.166, Activation: tanh, Epochs: 99, Batch Size: 43
# | 20        | -6.685    | 1.557     | 43.28     | 0.1664    | 99.54     | 113.3     |
# =====================================================================================
# Best Parameters: {'activation': 0.6430636235131795, 'batch_size': 29.3808212826125, 'dropout_rate': 0.1593029894309772, 'epochs': 99.05907619958839, 'num_units': 126.3384937205702}
# Epoch 1/99
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1259.0190 - mae: 25.8237 - val_loss: 221.2182 - val_mae: 12.0033
# Epoch 2/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 186.5138 - mae: 10.8247 - val_loss: 210.0527 - val_mae: 11.6404
# Epoch 3/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 167.2484 - mae: 10.1670 - val_loss: 186.4141 - val_mae: 10.9100
# Epoch 4/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 152.8161 - mae: 9.7527 - val_loss: 169.7654 - val_mae: 10.3514
# Epoch 5/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 139.4395 - mae: 9.2156 - val_loss: 168.4796 - val_mae: 10.2640
# Epoch 6/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 136.7145 - mae: 9.1290 - val_loss: 139.8483 - val_mae: 9.3385
# Epoch 7/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 127.9354 - mae: 8.8432 - val_loss: 125.7136 - val_mae: 8.8323
# Epoch 8/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 127.2641 - mae: 8.8272 - val_loss: 129.9696 - val_mae: 8.9615
# Epoch 9/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 122.4250 - mae: 8.5946 - val_loss: 126.1186 - val_mae: 8.8219
# Epoch 10/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 118.9088 - mae: 8.4896 - val_loss: 110.9516 - val_mae: 8.3000
# Epoch 11/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss:
99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73.5375 - mae: 6.5793 - val_loss: 84.6853 - val_mae: 7.0055
# Epoch 75/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 75.2903 - mae: 6.6765 - val_loss: 79.4346 - val_mae: 6.8806
# Epoch 76/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73.5910 - mae: 6.5836 - val_loss: 82.0213 - val_mae: 6.9520
# Epoch 77/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 74.5979 - mae: 6.6406 - val_loss: 81.8297 - val_mae: 6.9053
# Epoch 78/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.5131 - mae: 6.5561 - val_loss: 76.8191 - val_mae: 6.7375
# Epoch 79/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73.2339 - mae: 6.5644 - val_loss: 84.2644 - val_mae: 7.0325
# Epoch 80/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 74.0290 - mae: 6.5868 - val_loss: 79.1596 - val_mae: 6.7802
# Epoch 81/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.3627 - mae: 6.5603 - val_loss: 77.9182 - val_mae: 6.8784
# Epoch 82/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 74.1184 - mae: 6.6053 - val_loss: 90.3438 - val_mae: 7.2880
# Epoch 83/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.5588 - mae: 6.5504 - val_loss: 75.5958 - val_mae: 6.6092
# Epoch 84/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.2112 - mae: 6.5402 - val_loss: 87.0656 - val_mae: 7.1757
# Epoch 85/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.9039 - mae: 6.5160 - val_loss: 78.2102 - val_mae: 6.7747
# Epoch 86/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.2186 - mae: 6.5335 - val_loss: 85.7401 - val_mae: 7.1328
# Epoch 87/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.8959 - mae: 6.5241 - val_loss: 75.9759 - val_mae: 6.6382
# Epoch 88/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73.2873 - mae: 6.5880 - val_loss: 81.4537 - val_mae: 6.8585
# Epoch 89/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 70.5523 - mae: 6.4533 - val_loss: 87.2091 - val_mae: 7.1734
# Epoch 90/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.8482 - mae: 6.5356 - val_loss: 75.1555 - val_mae: 6.6009
# Epoch 91/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.6875 - mae: 6.5242 - val_loss: 80.5344 - val_mae: 6.9169
# Epoch 92/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.8019 - mae: 6.5126 - val_loss: 82.9910 - val_mae: 7.0648
# Epoch 93/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 70.8790 - mae: 6.4753 - val_loss: 86.3895 - val_mae: 7.1333
# Epoch 94/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.2498 - mae: 6.5041 - val_loss: 83.7807 - val_mae: 7.0009
# Epoch 95/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 72.5641 - mae: 6.5281 - val_loss: 82.1995 - val_mae: 6.9083
# Epoch 96/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.5075 - mae: 6.4830 - val_loss: 76.6106 - val_mae: 6.6291
# Epoch 97/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.5195 - mae: 6.4758 - val_loss: 81.5916 - val_mae: 6.9434
# Epoch 98/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 70.1732 - mae: 6.4529 - val_loss: 81.7212 - val_mae: 6.9130
# Epoch 99/99
# 991/991 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.7474 - mae: 6.4912 - val_loss: 79.2468 - val_mae: 6.6948
# Test MAE: 8.3522
# Test RMSE: 10.8116

# %% [markdown]
# MLP BM with all features (rolling statistics,, feature lagging, and time based features)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import math
from bayes_opt import BayesianOptimization  # For Bayesian Search

# Load and preprocess the dataset
def load_and_preprocess_data(filepath):
    try:
        df = pd.read_excel(filepath, engine="odf")  # Ensure the correct engine is used for ODS files
    except Exception as e:
        raise ValueError(f"Error reading the file: {e}")

    print("Columns in the dataset:", df.columns)

    if 'FECHA_HORA' not in df.columns:
        raise KeyError("The column 'FECHA_HORA' does not exist in the dataset.")
    
    # Convert 'FECHA_HORA' to datetime and set it as the index
    df['FECHA_HORA'] = pd.to_datetime(df['FECHA_HORA'], format='%d/%m/%Y %H:%M', errors='coerce')
    df.set_index('FECHA_HORA', inplace=True)
    
    # Clean the data: Convert all non-numeric cells to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(inplace=True)  # Drop rows with NaN values
    
    target_col = 'ALJARAFE-O3-AT_IN'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist in the dataset.")

    # Create lag features with a window size of 24
    lags = 24
    for i in range(1, lags + 1):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Add rolling statistics (mean, std, skewness) with a window size of 24
    df[f'{target_col}_rolling_mean'] = df[target_col].rolling(window=24).mean()
    df[f'{target_col}_rolling_std'] = df[target_col].rolling(window=24).std()
    df[f'{target_col}_rolling_skew'] = df[target_col].rolling(window=24).skew()
    
    # Add hourly and daily aggregated features
    df['hour'] = df.index.hour
    df['day'] = df.index.day
    df['weekday'] = df.index.weekday
    df['month'] = df.index.month

    df.dropna(inplace=True)  # Drop rows with NaN values after creating lag and rolling features
    return df, target_col

# Split the data into training and testing sets
def split_data(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
    split_index = int(len(df) * 0.8)
    X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test, scaler

# Build the MLP model
def build_mlp_model(input_dim, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential([
        Dense(num_units, activation=activation, input_shape=(input_dim,)),
        Dropout(dropout_rate),
        Dense(num_units // 2, activation=activation),
        Dense(1)  # Output layer for regression
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Objective function for Bayesian optimization
def objective_function(num_units, dropout_rate, activation, epochs, batch_size):
    activation = ['relu', 'tanh', 'sigmoid'][int(activation)]  # Convert to categorical choice
    num_units = int(num_units)
    epochs = int(epochs)
    batch_size = int(batch_size)
    
    model = build_mlp_model(X_train.shape[1], num_units=num_units, dropout_rate=dropout_rate, activation=activation)
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0)
    val_mae = np.min(history.history['val_mae'])  # Minimize validation MAE
    
    print(f"MAE: {val_mae}, Units: {num_units}, Dropout: {dropout_rate:.3f}, Activation: {activation}, Epochs: {epochs}, Batch Size: {batch_size}")
    return -val_mae  # We return negative because BayesianOptimization maximizes by default

# Hyperparameter optimization function using BayesianOptimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),  # Range for number of units
        'dropout_rate': (0.1, 0.5),  # Dropout rate
        'activation': (0, 2),  # 0: relu, 1: tanh, 2: sigmoid
        'epochs': (50, 100),  # Number of epochs
        'batch_size': (16, 64)  # Batch size
    }
    
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(num_units, dropout_rate, activation, epochs, batch_size),
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=5, n_iter=15)  # 5 initial points and 15 iterations of search
    
    print(f"Best Parameters: {optimizer.max['params']}")
    return optimizer.max['params']

# Visualize the training process
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['mae'], label='Training MAE')
    plt.plot(history.history['val_mae'], label='Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.title('Training and Validation MAE')
    plt.show()

# Evaluate the model and compute metrics
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0).flatten()
    mae = np.mean(np.abs(y_test - y_pred))
    rmse = math.sqrt(mean_squared_error(y_test, y_pred))
    
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    return mae, rmse

# Main function to execute the workflow
def main():
    global X_train, X_test, y_train, y_test  # Needed for the Bayesian objective function
    
    filepath = r"E:\Abroad period research\Time series forecasting\aljarafe_15-24 results\contaminacion_2015_2023.ods"
    
    try:
        df, target_col = load_and_preprocess_data(filepath)
        print("Data successfully loaded and cleaned.")
        
        X_train, X_test, y_train, y_test, scaler = split_data(df, target_col)
        
        # Optimize hyperparameters
        best_params = optimize_hyperparameters(X_train, y_train)
        
        # Train the final model with the best parameters
        final_model = build_mlp_model(
            input_dim=X_train.shape[1], 
            num_units=int(best_params['num_units']), 
            dropout_rate=best_params['dropout_rate'], 
            activation=['relu', 'tanh', 'sigmoid'][int(best_params['activation'])]
        )
        
        history = final_model.fit(X_train, y_train, epochs=int(best_params['epochs']), batch_size=int(best_params['batch_size']), validation_split=0.2, verbose=1)
        
        plot_training_history(history)
        mae, rmse = evaluate_model(final_model, X_test, y_test)
    
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Columns in the dataset: Index(['FECHA_HORA', 'ALJARAFE-DD-AT_IN', 'ALJARAFE-NO2-AT_IN',
#        'ALJARAFE-O3-AT_IN', 'ALJARAFE-PM10-AT_IN', 'ALJARAFE-TMP Media-AT_IN',
#        'ALJARAFE-VV-AT_IN'],
#       dtype='object')
# Data successfully loaded and cleaned.
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.886632919311523, Units: 46, Dropout: 0.393, Activation: relu, Epochs: 79, Batch Size: 61
# | 1         | -4.887    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.5819010734558105, Units: 99, Dropout: 0.446, Activation: relu, Epochs: 80, Batch Size: 18
# | 2         | -4.582    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.103679656982422, Units: 49, Dropout: 0.433, Activation: relu, Epochs: 60, Batch Size: 62
# | 3         | -5.104    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.192671298980713, Units: 59, Dropout: 0.310, Activation: relu, Epochs: 71, Batch Size: 30
# | 4         | -5.193    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.9916892051696777, Units: 75, Dropout: 0.217, Activation: tanh, Epochs: 68, Batch Size: 22
# | 5         | -3.992    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.138404846191406, Units: 90, Dropout: 0.203, Activation: relu, Epochs: 91, Batch Size: 49
# | 6         | -4.138    | 0.7742    | 49.17     | 0.2032    | 91.6      | 90.54     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 1.118123173713684, Units: 105, Dropout: 0.159, Activation: tanh, Epochs: 96, Batch Size: 21
# | 7         | -1.118    | 1.813     | 21.06     | 0.1589    | 96.26     | 106.0     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.02994441986084, Units: 54, Dropout: 0.114, Activation: tanh, Epochs: 55, Batch Size: 18
# | 8         | -4.03     | 1.168     | 18.29     | 0.1143    | 55.23     | 54.39     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 5.287072658538818, Units: 62, Dropout: 0.469, Activation: relu, Epochs: 71, Batch Size: 63
# | 9         | -5.287    | 0.9372    | 63.66     | 0.4687    | 71.59     | 62.29     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.592178821563721, Units: 107, Dropout: 0.335, Activation: relu, Epochs: 96, Batch Size: 21
# | 10        | -4.592    | 0.2431    | 21.23     | 0.3353    | 96.72     | 107.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.6377272605896, Units: 108, Dropout: 0.394, Activation: relu, Epochs: 79, Batch Size: 28
# | 11        | -4.638    | 0.9826    | 28.27     | 0.3941    | 79.79     | 108.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.790266990661621, Units: 60, Dropout: 0.287, Activation: relu, Epochs: 65, Batch Size: 54
# | 12        | -4.79     | 0.1509    | 54.97     | 0.2867    | 65.29     | 60.68     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.449571132659912, Units: 103, Dropout: 0.337, Activation: relu, Epochs: 87, Batch Size: 59
# | 13        | -4.45     | 0.165     | 59.38     | 0.3375    | 87.49     | 103.8     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.444065570831299, Units: 83, Dropout: 0.498, Activation: tanh, Epochs: 70, Batch Size: 48
# | 14        | -4.444    | 1.456     | 48.04     | 0.4978    | 70.33     | 83.72     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.38438606262207, Units: 53, Dropout: 0.221, Activation: relu, Epochs: 59, Batch Size: 51
# | 15        | -4.384    | 0.2672    | 51.39     | 0.2205    | 59.48     | 53.78     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.829061508178711, Units: 124, Dropout: 0.125, Activation: relu, Epochs: 87, Batch Size: 47
# | 16        | -3.829    | 0.5428    | 47.28     | 0.1249    | 87.35     | 124.1     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 3.9248087406158447, Units: 108, Dropout: 0.195, Activation: relu, Epochs: 95, Batch Size: 20
# | 17        | -3.925    | 0.3276    | 20.85     | 0.1952    | 95.61     | 108.3     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.568635940551758, Units: 47, Dropout: 0.435, Activation: tanh, Epochs: 96, Batch Size: 33
# | 18        | -4.569    | 1.555     | 33.16     | 0.435     | 96.73     | 47.66     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.20783805847168, Units: 120, Dropout: 0.417, Activation: tanh, Epochs: 66, Batch Size: 40
# | 19        | -4.208    | 1.011     | 40.56     | 0.4166    | 66.52     | 120.6     |
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# MAE: 4.424531936645508, Units: 59, Dropout: 0.267, Activation: tanh, Epochs: 59, Batch Size: 43
# | 20        | -4.425    | 1.728     | 43.46     | 0.2665    | 59.16     | 59.02     |
# =====================================================================================
# Best Parameters: {'activation': 1.812765080381792, 'batch_size': 21.05712181809413, 'dropout_rate': 0.15890981822640435, 'epochs': 96.26443771889072, 'num_units': 105.98762279823745}
# Epoch 1/96
# c:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2047.7775 - mae: 37.0498 - val_loss: 298.1816 - val_mae: 12.5979
# Epoch 2/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 308.5213 - mae: 12.1447 - val_loss: 94.2182 - val_mae: 7.1904
# Epoch 3/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss:
96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.5409 - mae: 4.0430 - val_loss: 27.6290 - val_mae: 3.8393
# Epoch 67/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.3717 - mae: 4.0571 - val_loss: 35.6394 - val_mae: 4.5326
# Epoch 68/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.7515 - mae: 4.0793 - val_loss: 29.6000 - val_mae: 4.0425
# Epoch 69/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.0098 - mae: 4.0289 - val_loss: 32.4893 - val_mae: 4.2495
# Epoch 70/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.0343 - mae: 4.0328 - val_loss: 25.0359 - val_mae: 3.6282
# Epoch 71/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 27.9357 - mae: 3.9802 - val_loss: 26.3782 - val_mae: 3.7456
# Epoch 72/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 29.3279 - mae: 4.0448 - val_loss: 25.8407 - val_mae: 3.7322
# Epoch 73/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 28.1640 - mae: 3.9780 - val_loss: 24.1956 - val_mae: 3.5898
# Epoch 74/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 27.6197 - mae: 3.9327 - val_loss: 28.4841 - val_mae: 3.9632
# Epoch 75/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 26.8025 - mae: 3.8878 - val_loss: 23.8797 - val_mae: 3.6039
# Epoch 76/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 26.1488 - mae: 3.8430 - val_loss: 40.6709 - val_mae: 5.1198
# Epoch 77/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 26.7547 - mae: 3.8786 - val_loss: 24.7705 - val_mae: 3.7192
# Epoch 78/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 25.3023 - mae: 3.7738 - val_loss: 23.6088 - val_mae: 3.6060
# Epoch 79/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.7685 - mae: 3.7567 - val_loss: 33.9680 - val_mae: 4.6363
# Epoch 80/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 23.6561 - mae: 3.6798 - val_loss: 18.0228 - val_mae: 3.1463
# Epoch 81/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 22.1646 - mae: 3.5596 - val_loss: 18.0526 - val_mae: 3.1438
# Epoch 82/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 21.3001 - mae: 3.4892 - val_loss: 15.5185 - val_mae: 2.8858
# Epoch 83/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 21.1134 - mae: 3.4656 - val_loss: 15.0946 - val_mae: 2.8868
# Epoch 84/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 18.4565 - mae: 3.2714 - val_loss: 12.3393 - val_mae: 2.5751
# Epoch 85/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 17.5025 - mae: 3.1928 - val_loss: 16.7889 - val_mae: 3.2311
# Epoch 86/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 16.2651 - mae: 3.0771 - val_loss: 18.9032 - val_mae: 3.5579
# Epoch 87/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 15.5090 - mae: 3.0296 - val_loss: 7.8269 - val_mae: 2.0574
# Epoch 88/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13.0303 - mae: 2.7590 - val_loss: 6.2805 - val_mae: 1.8760
# Epoch 89/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.4424 - mae: 2.7221 - val_loss: 7.1342 - val_mae: 2.1081
# Epoch 90/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1453 - mae: 2.5803 - val_loss: 12.3576 - val_mae: 3.0077
# Epoch 91/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.9017 - mae: 2.5396 - val_loss: 7.0970 - val_mae: 2.1656
# Epoch 92/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.2850 - mae: 2.4771 - val_loss: 3.4196 - val_mae: 1.3965
# Epoch 93/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.9843 - mae: 2.3025 - val_loss: 3.0812 - val_mae: 1.3293
# Epoch 94/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.1686 - mae: 2.3347 - val_loss: 2.7440 - val_mae: 1.2436
# Epoch 95/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.8830 - mae: 2.2979 - val_loss: 2.3099 - val_mae: 1.1251
# Epoch 96/96
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.7858 - mae: 2.2824 - val_loss: 4.4961 - val_mae: 1.7490
# Test MAE: 2.0014
# Test RMSE: 2.4472
